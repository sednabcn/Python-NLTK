# %% [markdown]
# <h1>TEXT SUMMARIZTION WITH AMAZON-REVIEWS</h1>

# %%
from distutils.version import LooseVersion
import tensorflow as tf
from tensorflow.python.layers.core import Dense


# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.1'), 'Please use TensorFlow version 1.1 or newer'
# !python3.6 -m pip install tensorflow==1.15
# Out:
# Requirement already satisfied: tensorflow==1.15 in /usr/local/lib/python3.6/dist-packages (1.15.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.12.1)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.28.1)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (3.10.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.18.4)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (0.2.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.12.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (0.8.1)
# Requirement already satisfied: tensorboard<1.16.0,>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.15.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (0.34.2)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (0.9.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.1.0)
# Requirement already satisfied: tensorflow-estimator==1.15.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.15.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (3.2.1)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.1.0)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.0.8)
# Requirement already satisfied: gast==0.2.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (0.2.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow==1.15) (46.1.3)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (3.2.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow==1.15) (2.10.0)

# %%
import tensorflow as tf
print(tf.__version__)
dir(tf.contrib.rnn)
# Out:
# 1.15.0
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
# ['AttentionCellWrapper',
#  'BasicLSTMCell',
#  'BasicRNNCell',
#  'BidirectionalGridLSTMCell',
#  'CompiledWrapper',
#  'Conv1DLSTMCell',
#  'Conv2DLSTMCell',
#  'Conv3DLSTMCell',
#  'ConvLSTMCell',
#  'CoupledInputForgetGateLSTMCell',
#  'DeviceWrapper',
#  'DropoutWrapper',
#  'EmbeddingWrapper',
#  'FusedRNNCell',
#  'FusedRNNCellAdaptor',
#  'GLSTMCell',
#  'GRUBlockCell',
#  'GRUBlockCellV2',
#  'GRUCell',
#  'GridLSTMCell',
#  'HighwayWrapper',
#  'IndRNNCell',
#  'IndyGRUCell',
#  'IndyLSTMCell',
#  'InputProjectionWrapper',
#  'IntersectionRNNCell',
#  'LSTMBlockCell',
#  'LSTMBlockFusedCell',
#  'LSTMBlockWrapper',
#  'LSTMCell',
#  'LSTMStateTuple',
#  'LayerNormBasicLSTMCell',
#  'LayerRNNCell',
#  'MultiRNNCell',
#  'NASCell',
#  'OutputProjectionWrapper',
#  'PhasedLSTMCell',
#  'RNNCell',
#  'ResidualWrapper',
#  'SRUCell',
#  'TimeFreqLSTMCell',
#  'TimeReversedFusedRNN',
#  'UGRNNCell',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'best_effort_input_batch_size',
#  'stack_bidirectional_dynamic_rnn',
#  'stack_bidirectional_rnn',
#  'static_bidirectional_rnn',
#  'static_rnn',
#  'static_state_saving_rnn',
#  'transpose_batch_time']

# %%
import pandas as pd
import tensorflow as tf
import numpy as np
import gzip
import codecs
import re
import time
from tensorflow.python.ops.rnn_cell_impl import _zero_state_tensors
from tensorflow.python.layers.core import Dense
from tensorflow.contrib.rnn import GRUCell, DropoutWrapper
from tensorflow.contrib.seq2seq import TrainingHelper, GreedyEmbeddingHelper,BasicDecoder, dynamic_decode, \
 BahdanauAttention, AttentionWrapper,sequence_loss
import helper

TOKEN_GO = '<GO>'
TOKEN_EOS = '<EOS>'
TOKEN_PAD = '<PAD>'
TOKEN_UNK = '<UNK>'

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
from numpy import linalg as LA
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
import os
os.listdir('/content/gdrive/My Drive')
# Out:
# ['NewsAggregatorDataset.zip',
#  '02_example.ipynb',
#  'Colab Notebooks',
#  'IMG-20191005-WA0001.jpg',
#  'prepared_test_data.tsv',
#  'prepared_train_data.tsv',
#  'prepared_validation_data.tsv',
#  'starspace_stackoverflow_model_03',
#  'starspace_stackoverflow_model_03.tsv',
#  'starspace_stackoverflow_model_03.txt',
#  'test_embeddings.tsv',
#  'test.tsv',
#  'train.tsv',
#  'validation.tsv',
#  'Rebut.pdf',
#  'CONCURSO',
#  'aqu-cert-cong-01.zip',
#  'AQU-2016-17a.zip',
#  'AQU-2016-17b.zip',
#  'aqu-cert-cong-03.zip',
#  'aqu-cert-cong-02.zip',
#  'aqu-cert-cong-04.zip',
#  'aqu-cert-cong-07.zip',
#  'aqu-cert-cong-06.zip',
#  'aqu-cert-cong-05.zip',
#  'aqu-other-03.zip',
#  'aqu-other-01.zip',
#  'aqu-other-02.zip',
#  'aqu-publi-01.zip',
#  'aqu-publi-02.zip',
#  'COURSERA-CERTIFICATIONS.zip',
#  'aqu-publi-03.zip',
#  'aqu-publi-04.zip',
#  'docs-01.zip',
#  'docs-02.zip',
#  'docs-03.zip',
#  'docs-04.zip',
#  'docs-05.zip',
#  'docs-06.zip',
#  'docs-07.zip',
#  'docs-09.zip',
#  'docs-08.zip',
#  'docs-10.zip',
#  'docs-12.zip',
#  'docs-11.zip',
#  'SEMINAR.zip',
#  'Titols-02.zip',
#  'unsl1213.split.zip',
#  'Titols-01.zip',
#  'Report.docx',
#  'Report.gdoc',
#  'Colabs_data',
#  'Python-NLTK',
#  'data-protfolio.ppt',
#  '20200417_220825.jpg',
#  '20200417_214248.jpg',
#  '20200417_223046.jpg',
#  '20200420_163316.jpg',
#  '20200420_165338.jpg',
#  'q2c 20-Apr-2020 18-13-28(2).pdf',
#  'docs_python_org_3_library_re_html.pdf',
#  'attention.py',
#  'news.txt.gz',
#  'summary.txt.gz',
#  'glove6b50dtxt.zip',
#  'cc.ca.300.vec.gz',
#  'cc.en.300.vec.gz',
#  'data_new.csv',
#  'best_so_far_model.ckpt.index',
#  'checkpoint',
#  'best_so_far_model.ckpt.data-00000-of-00001',
#  'best_so_far_model.ckpt.meta',
#  'events.out.tfevents.1589529082.2356474a121a',
#  'events.out.tfevents.1589533377.2356474a121a',
#  'events.out.tfevents.1589534224.2356474a121a',
#  'events.out.tfevents.1589535405.2356474a121a',
#  'events.out.tfevents.1589540456.2356474a121a']

# %%
#titledata=[]
#artdata=[]
#with gzip.open('/content/gdrive/My Drive/news.txt.gz') as artfile:
#    for li in artfile:
#        artdata.append(li.decode())
#with gzip.open('/content/gdrive/My Drive/summary.txt.gz') as titlefile:
#    for li in titlefile:
#        titledata.append(li.decode())
#news = pd.DataFrame({'Text':artdata,'Summary':titledata})
#news = news.sample(frac=0.5)
#news['Text_len'] = news.Text.apply(lambda x: len(x.split()))
#news['Summary_len'] = news.Summary.apply(lambda x: len(x.split()))

# %%
data_new=pd.read_csv('/content/gdrive/My Drive/data_new.csv')

# %%
news=data_new[['cleaned_text','cleaned_summary']]
news=news.rename(columns={'cleaned_text':'Text','cleaned_summary':'Summary'})
news['Text_len'] = news.Text.apply(lambda x: len(x.split()))
news['Summary_len'] = news.Summary.apply(lambda x: len(x.split()))
news.head()
# Out:
#                                                 Text  ... Summary_len
# 0  bought several vitality canned dog food produc...  ...           4
# 1  product arrived labeled jumbo salted peanuts p...  ...           3
# 2  confection around centuries light pillowy citr...  ...           4
# 3  looking secret ingredient robitussin believe f...  ...           2
# 4  great taffy great price wide assortment yummy ...  ...           2
#
# [5 rows x 4 columns]

# %%
print(news['Text'].head(5).values)
print(news['Summary'].head(5).values)
# Out:
# ['bought several vitality canned dog food products found good quality product looks like stew processed meat smells better labrador finicky appreciates product better'
#  'product arrived labeled jumbo salted peanuts peanuts actually small sized unsalted sure error vendor intended represent product jumbo'
#  'confection around centuries light pillowy citrus gelatin nuts case filberts cut tiny squares liberally coated powdered sugar tiny mouthful heaven chewy flavorful highly recommend yummy treat familiar story lewis lion witch wardrobe treat seduces edmund selling brother sisters witch'
#  'looking secret ingredient robitussin believe found got addition root beer extract ordered made cherry soda flavor medicinal'
#  'great taffy great price wide assortment yummy taffy delivery quick taffy lover deal']
# ['good quality dog food ' 'not as advertised ' 'delight says it all '
#  'cough medicine ' 'great taffy ']

# %%
news_summaries = []
for summary in news.Summary:
    news_summaries.append(summary)
news_texts = []
for text in news.Text:
    news_texts.append(text)

# %%
def count_words(words_dict, text):
    for sentence in text:
        for word in sentence.split():
            if word not in words_dict:
                words_dict[word] = 1
            else:
                words_dict[word] += 1

# %%
word_counts_dict = {}
count_words(word_counts_dict, news_summaries)
count_words(word_counts_dict, news_texts)
            
print("Total words in Vocabulary:", len(word_counts_dict))
# Out:
# Total words in Vocabulary: 56955

# %%
if 'glove.6B.50d.txt' not in os.listdir('/content/'):
  # !unzip /content/gdrive/My\ Drive/glove6b50dtxt.zip

# %%
def build_word_vector_matrix(vector_file):
    embedding_index = {}
    with codecs.open(vector_file, 'r', 'utf-8') as f:
        for i, line in enumerate(f):
            sr = line.split()
            if(len(sr)<26):
                continue
            word = sr[0]
            embedding = np.asarray(sr[1:], dtype='float32')
            embedding_index[word] = embedding
    return embedding_index
# Replace the path here to point to the glove.6B.50d.txt vectors file on your system
embeddings_index = build_word_vector_matrix('/content/glove.6B.50d.txt')

# %%
word2int = {} 
count_threshold = 20
value = 0
for word, count in word_counts_dict.items():
    if count >= count_threshold or word in embeddings_index:
        word2int[word] = value
        value += 1


special_codes = [TOKEN_UNK,TOKEN_PAD,TOKEN_EOS,TOKEN_GO]   

for code in special_codes:
    word2int[code] = len(word2int)

int2word = {}
for word, value in word2int.items():
    int2word[value] = word

# %%
embedding_dim = 50
nwords = len(word2int)

word_emb_matrix = np.zeros((nwords, embedding_dim), dtype=np.float32)
for word, i in word2int.items():
    if word in embeddings_index:
        word_emb_matrix[i] = embeddings_index[word]
    else:
        new_embedding = np.array(np.random.uniform(-1.0, 1.0, embedding_dim))
        word_emb_matrix[i] = new_embedding
print("Length of word embeddings: ", len(word_emb_matrix))
# Out:
# Length of word embeddings:  36805

# %%
def convert_sentence_to_ids(text, eos=False):
    wordints = []
    word_count = 0
    for sentence in text:
        sentence2ints = []
        for word in sentence.split():
            word_count += 1
            if word in word2int:
                sentence2ints.append(word2int[word])
            else:
                sentence2ints.append(word2int[TOKEN_UNK])
        if eos:
            sentence2ints.append(word2int[TOKEN_EOS])
        wordints.append(sentence2ints)
    return wordints, word_count

# %%
id_summaries, word_count = convert_sentence_to_ids(news_summaries)
id_texts, word_count = convert_sentence_to_ids(news_texts, eos=True)

# %%
def unknown_tokens(sentence):
    unk_token_count = 0
    for word in sentence:
        if word == word2int[TOKEN_UNK]:
            unk_token_count += 1
    return unk_token_count

# %%
news_summaries_filtered = []
news_texts_filtered = []
max_text_length = int(news.Text_len.mean() + news.Text_len.std())
max_summary_length = int(int(news.Summary_len.mean() + news.Summary_len.std()))
min_length = 4
unknown_token_text_limit = 10
unknown_token_summary_limit = 4

for count,text in enumerate(id_texts):
    unknown_token_text = unknown_tokens(id_texts[count])
    unknown_token_summary = unknown_tokens(id_summaries[count])
    text_len = len(id_texts[count])
    summary_len = len(id_summaries[count])
    if((unknown_token_text>unknown_token_text_limit) or (unknown_token_summary>unknown_token_summary_limit)):
        continue
    if(text_len<min_length or summary_len<min_length or text_len>max_text_length or summary_len>max_summary_length):
        continue
    news_summaries_filtered.append(id_summaries[count])
    news_texts_filtered.append(id_texts[count])

# %%
def model_inputs():
    inputs_data = tf.placeholder(tf.int32, [None, None], name='input_data')
    targets = tf.placeholder(tf.int32, [None, None], name='targets')
    learning_rate = tf.placeholder(tf.float32, name='learning_rate')
    dropout_probs = tf.placeholder(tf.float32, name='dropout_probs')
    summary_len = tf.placeholder(tf.int32, (None,), name='summary_len')
    max_summary_len = tf.reduce_max(summary_len, name='max_summary_len')
    text_len = tf.placeholder(tf.int32, (None,), name='text_len')
    return inputs_data, targets, learning_rate, dropout_probs, summary_len, max_summary_len, text_len

# %%
def process_encoding_input(target_data, word2int, batch_size):
    ending = tf.strided_slice(target_data, [0, 0], [batch_size, -1], [1, 1])
    decoding_input = tf.concat([tf.fill([batch_size, 1], word2int[TOKEN_GO]), ending], 1)
    return decoding_input

# %%
def get_cell(csize,dprob):
    rnc = GRUCell(csize)
    rnc = DropoutWrapper(rnc, input_keep_prob = dprob)
    return rnc

def encoding_layer(csize, len_s, nl, rinp, dprob):
    for l in range(nl):
        with tf.variable_scope('encoding_l_{}'.format(l)):
            rnn_frnt = get_cell(csize,dprob)
            rnn_bkwd = get_cell(csize,dprob)
            eop, est = tf.nn.bidirectional_dynamic_rnn(rnn_frnt, rnn_bkwd, 
                                                                    rinp,
                                                                    len_s,
                                                                    dtype=tf.float32)
    eop = tf.concat(eop,nl)
    return eop, est

# %%
def trng_dec_layer(dec_emb_inp, summ_len, cell_dec, st_init, lyr_op, 
                            v_size, max_summ_len):
    helper = TrainingHelper(inputs=dec_emb_inp,sequence_length=summ_len, time_major=False)
    dec = BasicDecoder(cell_dec,helper,st_init,lyr_op) 
    logits, _, _ = dynamic_decode(dec,output_time_major=False,impute_finished=True, 
                                  maximum_iterations=max_summ_len)
    return logits

# %%
def infr_dec_layer(embeddings, start_token, end_token, decoding_cell, initial_state, op_layer,
                             max_summary_len, batch_size):
    
    start_tokens = tf.tile(tf.constant([start_token], dtype=tf.int32), [batch_size], name='start_tokens')
    inf_helper = GreedyEmbeddingHelper(embeddings,start_tokens,end_token)
    inf_decoder = BasicDecoder(decoding_cell,inf_helper,initial_state,op_layer)       
    inf_logits, _, _ = dynamic_decode(inf_decoder,output_time_major=False,impute_finished=True,
                                                            maximum_iterations=max_summary_len)
    return inf_logits

# %%
def decoding_layer(dec_emb_op, embs, enc_op, enc_st, v_size, txt_len, 
                   summ_len,mx_summ_len, rnsize, word2int, dprob, batch_size, nlyrs):
    
    for l in range(nlyrs):
        with tf.variable_scope('dec_rnn_layer_{}'.format(l)):
            gru = tf.contrib.rnn.GRUCell(rnn_len)
            cell_dec = tf.contrib.rnn.DropoutWrapper(gru,input_keep_prob = dprob)
            
    out_l = Dense(v_size, kernel_initializer = tf.truncated_normal_initializer(mean = 0.0, stddev=0.1))
    
    attention = BahdanauAttention(rnsize, enc_op,txt_len,
                                                  normalize=False,
                                                  name='BahdanauAttention')
    cell_dec =  AttentionWrapper(cell_dec,attention,rnn_len)
    attn_zstate = cell_dec.zero_state(batch_size , tf.float32 )
    attn_zstate = attn_zstate.clone(cell_state = enc_st[0])
    with tf.variable_scope("decoding_layer"):
        tr_dec_op = trng_dec_layer(dec_emb_op, 
                                                  summ_len, 
                                                  cell_dec, 
                                                  attn_zstate,
                                                  out_l,
                                                  v_size, 
                                                  mx_summ_len)
    with tf.variable_scope("decoding_layer", reuse=True):
        inf_dec_op = infr_dec_layer(embs,  
                                                    word2int[TOKEN_GO], 
                                                    word2int[TOKEN_EOS],
                                                    cell_dec, 
                                                    attn_zstate, 
                                                    out_l,
                                                    mx_summ_len,
                                                    batch_size)

    return tr_dec_op, inf_dec_op

# %%
def seq2seq_model(data_inp, data_summ_tgt, dprob, len_txt, len_summ, max_len_summ, 
                  v_size, rnsize, nlyrs, word2int, batch_size):
    
    inp_emb = word_emb_matrix
    word_embs = tf.Variable(inp_emb, name="word_embs")
    inp_enc_emb = tf.nn.embedding_lookup(word_embs, data_inp)
    op_enc, st_enc = encoding_layer(rnsize, len_txt, nlyrs, inp_enc_emb, dprob)
    
    inp_dec = process_encoding_input(data_summ_tgt, word2int, batch_size)
    inp_dec_emb = tf.nn.embedding_lookup(inp_emb, inp_dec)
    
    op_tr, op_inf  = decoding_layer(inp_dec_emb, 
                                                        inp_emb,
                                                        op_enc,
                                                        st_enc, 
                                                        v_size, 
                                                        len_txt, 
                                                        len_summ, 
                                                        max_len_summ,
                                                        rnsize, 
                                                        word2int, 
                                                        dprob, 
                                                        batch_size,
                                                        nlyrs)
    
    return op_tr, op_inf

# %%
def pad_sentences(sentences_batch):

    max_sentence = max([len(sentence) for sentence in sentences_batch])
    return [sentence + [word2int[TOKEN_PAD]] * (max_sentence - len(sentence)) for sentence in sentences_batch]

# %%
def get_batches(summaries, texts, batch_size):
    for batch_idx in range(0, len(texts)//batch_size):
        start_idx = batch_idx * batch_size
        summaries_batch = summaries[start_idx:start_idx + batch_size]
        texts_batch = texts[start_idx:start_idx + batch_size]
        pad_summaries_batch = np.array(pad_sentences(summaries_batch))
        pad_texts_batch = np.array(pad_sentences(texts_batch))

        pad_summaries_lens = []
        for summary in pad_summaries_batch:
            pad_summaries_lens.append(len(summary))
        
        pad_texts_lens = []
        for text in pad_texts_batch:
            pad_texts_lens.append(len(text))
        
        yield pad_summaries_batch, pad_texts_batch, pad_summaries_lens, pad_texts_lens

# %%
def train_on_batch(session, X, X_seq_len, Y, Y_seq_len, learning_rate, dropout_keep_probability):
    feed_dict = {
            data_inp: X,
            tgts:Y,
            lrt:learning_rate,
            len_summ:Y_seq_len,
            len_txt: X_seq_len,
            dprobs: dropout_keep_probability}

    _,pred,loss,summary = session.run([
            train_op,
            tr_cost,
            inf_op,
            merged_summary_op], feed_dict=feed_dict)
    return _,pred, loss, summary

# %%
def predict_for_batch(session, X, X_seq_len,Y, Y_seq_len,dropout_keep_probability):

    feed_dict={data_inp:X, len_txt:X_seq_len,tgts:Y, len_summ: Y_seq_len,dprobs: dropout_keep_probability}

    pred = session.run([inf_op], feed_dict=feed_dict)[0]

    return pred

# %%
def predict_for_batch_with_loss(session, X, X_seq_len, Y, Y_seq_len,learning_rate,dropout_keep_probability):
    
    feed_dict={data_inp:X, len_txt:X_seq_len, tgts:Y, len_summ: Y_seq_len,lrt:learning_rate,dprobs: dropout_keep_probability}
    
    _,loss,pred = session.run([train_op,tr_cost,infer_predictions], feed_dict=feed_dict)
    
    return pred, loss

# %%
batch_size = 64
rnn_len = 256
n_layers = 2
lr = 0.005
dr_prob =0.75
logs_path='/content/gdrive/My Drive/'

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    
    data_inp, tgts, lrt, dprobs, len_summ, max_len_summ, len_txt = model_inputs()

    tr_opp, inf_opp = seq2seq_model(tf.reverse(data_inp, [-1]),
                                                      tgts, 
                                                      dprobs,   
                                                      len_txt,
                                                      len_summ,
                                                      max_len_summ,
                                                      len(word2int)+1,
                                                      rnn_len, 
                                                      n_layers, 
                                                      word2int,
                                                      batch_size)
    
    tr_op = tf.identity(tr_opp.rnn_output, 'tr_op')
    inf_op = tf.identity(inf_opp.sample_id, name='predictions')
    
    seq_masks = tf.sequence_mask(len_summ, max_len_summ, dtype=tf.float32, name='masks')

    with tf.name_scope("optimizer"):
        tr_cost = sequence_loss(tr_op,tgts,seq_masks)
        optzr = tf.train.AdamOptimizer(lrt)
        grds = optzr.compute_gradients(tr_cost)
        capped_grds = [(tf.clip_by_value(grd, -5., 5.), var) for grd, var in grds 
                        if grd is not None]
        train_op = optzr.apply_gradients(capped_grds)
    # Get predictions for evaluation.
    train_predictions = tr_opp.sample_id
    infer_predictions = inf_opp.sample_id
    tf.summary.scalar("cost", tr_cost)
print("Graph created.")
# Out:
# WARNING:tensorflow:From <ipython-input-24-08a5f0b64492>:2: GRUCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.GRUCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From <ipython-input-24-08a5f0b64492>:14: bidirectional_dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.Bidirectional(keras.layers.RNN(cell))`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn.py:464: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn_cell_impl.py:559: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn_cell_impl.py:565: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn_cell_impl.py:575: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn.py:244: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Graph created.

# %%
def text_to_seq(text):
    return [word2int.get(word, word2int[TOKEN_UNK]) for word in text.split()]

# %%
# Program to measure similarity between  
# two sentences using cosine similarity. 
def mean_absolute_error_texts(v1,v2):
    meanerrorl2=[]
    for X,Y in zip(v1,v2):
        # tokenization 
        X_list = word_tokenize(X)  
        Y_list = word_tokenize(Y) 
  
        # sw contains the list of stopwords 
        sw = stopwords.words('english')  
        l1 =[];l2 =[] 
  
        # remove stop words from string 
        X_set = {w for w in X if not w in sw}  
        Y_set = {w for w in Y if not w in sw} 
  
        # form a set containing keywords of both strings  
        rvector = X_set.union(Y_set)  
        for w in rvector: 
            if w in X_set:
               l1.append(1) # create a vector 
            else:
               l1.append(0) 
            if w in Y_set:
               l2.append(1) 
            else:
               l2.append(0) 
        c = 0
        # cosine formula  
        for i in range(len(rvector)): 
                      c+= l1[i]*l2[i] 
        den=float((sum(l1)*sum(l2))**0.5)
        try: 
           cosine = c /den
        except:
           cosine=0.0 
        meanerrorl2.append(cosine) 
    return LA.norm(meanerrorl2,2)*100.0

# %%
len(news_summaries_filtered)
# Out:
# 27125

# %%
len(news_texts_filtered)
# Out:
# 27125

# %%
epochs =5
min_learning_rate = 0.0006
display_step = 50
early_stop_cnt = 0 
early_stop_cnt_max = 3 
per_epoch = 3 


update_loss = 0 
batch_loss = 0
summary_update_loss = [] 

news_summaries_train = news_summaries_filtered[0:21700]
news_texts_train = news_texts_filtered[0:21700]

news_summaries_test =news_summaries_filtered[21700:]
news_texts_test=news_texts_filtered[21700:]

pad = word2int[TOKEN_PAD] 
eos = word2int[TOKEN_EOS]  
unk = word2int[TOKEN_UNK]
tokens_id=[eos,pad,unk]

update_check = (len(news_texts_train)//batch_size//per_epoch)-1
checkpoint = logs_path + 'best_so_far_model.ckpt'

# %%
invalid_number_prediction_counts = []
all_model_predictions = []
all_ground_truth = []
history=[]
print('Start training... \n')

with tf.Session(graph=train_graph) as sess:
    tf_summary_writer = tf.summary.FileWriter(logs_path, graph=train_graph)
    merged_summary_op = tf.summary.merge_all()
    sess.run(tf.global_variables_initializer())
    for epoch_i in range(epochs):
        update_loss = 0
        batch_loss = 0
        train_loss =0
        for batch_i, (summaries_batch, texts_batch, summaries_len, texts_len) in enumerate(
                get_batches(news_summaries_train, news_texts_train, batch_size)):
            before = time.time()
            _,loss,predictions,summary=train_on_batch(sess,texts_batch, texts_len, summaries_batch, summaries_len, lr, dr_prob)
            #_,loss,summary = sess.run(
            #    [train_op, tr_cost,merged_summary_op],
            #    {data_inp: texts_batch,
            #     tgts: summaries_batch,
            #     lrt: lr,
            #     len_summ: summaries_len,
            #     len_txt: texts_len,
            #     dprobs: dr_prob})
            
            batch_loss += loss
            update_loss += loss
            after = time.time()
            batch_time = after - before
            tf_summary_writer.add_summary(summary, epoch_i * batch_size + batch_i)
            
            if batch_i % display_step == 0 and batch_i > 0:
                print('** Epoch {:>3}/{} Batch {:>4}/{} - Batch Loss: {:>6.3f}, seconds: {:>4.2f}'
                      .format(epoch_i+1,
                              epochs, 
                              batch_i, 
                              len(news_texts_filtered) // batch_size, 
                              batch_loss / display_step, 
                              batch_time*display_step))
                batch_loss = 0
            
            if batch_i % update_check == 0 and batch_i > 0:
                print("Average loss:", round(update_loss/update_check,3))
                train_loss=round(update_loss/update_check,3)
                summary_update_loss.append(update_loss)
                
                if update_loss <= min(summary_update_loss):
                    print('Saving model') 
                    early_stop_cnt = 0
                    saver = tf.train.Saver() 
                    saver.save(sess, checkpoint)

                else:
                    print("No Improvement.")
                    early_stop_cnt += 1
                    if early_stop_cnt == early_stop_cnt_max:
                        break
                update_loss = 0

        summaries_test_batch, texts_test_batch, summaries_test_len, texts_test_len =\
         next(get_batches(news_summaries_test, news_texts_test, batch_size))
    
        predictions,test_loss = predict_for_batch_with_loss(sess,texts_test_batch, texts_test_len,summaries_test_batch,summaries_test_len,lr,1.0)
        history.append([epoch_i+1,train_loss,test_loss])
        print('history:',history[-1])
        print(" ")  
        print('Test: epoch', epoch_i+1, 'loss:', test_loss,)
        print(" ")
        for text, summary, result_logits  in list(zip(texts_test_batch, summaries_test_batch, predictions))[-3:]: 
                     print('\nText')
                     print('  Word Ids:    {}'.format([i for i in text]))
                     print('  Input Words: {}'.format(" ".join( int2word[i] for i in text if i not in tokens_id)))

                     print('\nSummary')
                     print('  Word Ids:       {}'.format([i for i in result_logits if i not in tokens_id]))
                     print('  Response Words: {}'.format(" ".join(int2word[i] for i in result_logits if i not in tokens_id )))
                     print(' Ground Truth: {}'.format(" ".join(int2word[i] for i in summary if i not in tokens_id)))
                     print('')
        model_predictions = []
        ground_truth = []
        invalid_number_prediction_count = 0

        ind=0
        for summaries_test_batch, texts_test_batch, summaries_test_len, texts_test_len\
         in get_batches(news_summaries_test,news_texts_test, batch_size=batch_size):
                 
  
                 #summaries_test_len=[np.random.randint(5,8)]
                 pred=predict_for_batch(sess, texts_test_batch, texts_test_len,summaries_test_batch,summaries_test_len,1.0)   
                 
                 for y,p in list(zip(summaries_test_batch,pred)): 
                     Y=''.join(int2word[i] for i in y if i not in tokens_id)
                     O=''.join(int2word[i] for i in p if i not in tokens_id)
                     
                     if mean_absolute_error_texts([Y],[O])<1e-15 : 
                             invalid_number_prediction_count += 1
                     lmin=min(len(Y),len(O))+1
                     OO=O[:lmin]
                     YY=Y[:lmin] 
                     model_predictions.append(OO)
                     ground_truth.append(YY)
        all_model_predictions.append(model_predictions)
        all_ground_truth.append(ground_truth)
        invalid_number_prediction_counts.append(invalid_number_prediction_count)
         
        if early_stop_cnt == early_stop_cnt_max:
            print("Stopping Training.")
            break
# Out:
# Start training...
#
# ** Epoch   1/5 Batch   50/423 - Batch Loss:  6.672, seconds: 84.59
# ** Epoch   1/5 Batch  100/423 - Batch Loss:  5.414, seconds: 82.07
# Average loss: 5.982
# Saving model
# ** Epoch   1/5 Batch  150/423 - Batch Loss:  5.269, seconds: 82.79
# ** Epoch   1/5 Batch  200/423 - Batch Loss:  5.103, seconds: 82.21
# Average loss: 5.142
# Saving model
# ** Epoch   1/5 Batch  250/423 - Batch Loss:  4.992, seconds: 81.48
# ** Epoch   1/5 Batch  300/423 - Batch Loss:  4.878, seconds: 84.69
# Average loss: 4.909
# Saving model
# history: [1, 4.909, 4.832585]
#
# Test: epoch 1 loss: 4.832585
#
#
# Text
#   Word Ids:    [25, 2127, 258, 165, 1890, 156, 83, 2296, 496, 13, 145, 1032, 61, 181, 81, 82, 36803, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802]
#   Input Words: best afternoon snack ever put bag way school work great source protein product natural gluten free
#
# Summary
#   Word Ids:       [13, 258, 44, 24, 258]
#   Response Words: great snack and healthy snack
#  Ground Truth: great gluten free snack
#
#
# Text
#   Word Ids:    [13305, 746, 845, 1017, 695, 1472, 1458, 1445, 1017, 3178, 2545, 60, 4367, 149, 1064, 771, 433, 1285, 36801, 1874, 1802, 1472, 36803, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802]
#   Input Words: confess addicted kind bars first try blueberry pistachio bars sealed problem delicious fairly low calories sometimes use meal feel satisfied try
#
# Summary
#   Word Ids:       [13, 258, 70, 17, 115]
#   Response Words: great snack for the go
#  Ground Truth: addicted to kind bars
#
#
# Text
#   Word Ids:    [32, 1017, 1089, 1082, 1874, 1576, 258, 21, 684, 24, 36803, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802]
#   Input Words: love bars run quickly feel guilty snack tasty yet healthy
#
# Summary
#   Word Ids:       [13, 258, 44, 24, 258]
#   Response Words: great snack and healthy snack
#  Ground Truth: these are the best
#
# ** Epoch   2/5 Batch   50/423 - Batch Loss:  4.617, seconds: 85.45
# ** Epoch   2/5 Batch  100/423 - Batch Loss:  4.340, seconds: 82.37
# Average loss: 4.476
# Saving model
# ** Epoch   2/5 Batch  150/423 - Batch Loss:  4.377, seconds: 85.52
# ** Epoch   2/5 Batch  200/423 - Batch Loss:  4.329, seconds: 82.81
# Average loss: 4.352
# Saving model
# ** Epoch   2/5 Batch  250/423 - Batch Loss:  4.299, seconds: 82.94
# ** Epoch   2/5 Batch  300/423 - Batch Loss:  4.237, seconds: 83.50
# Average loss: 4.251
# Saving model
# history: [2, 4.251, 4.3669915]
#
# Test: epoch 2 loss: 4.3669915
#
#
# Text
#   Word Ids:    [25, 2127, 258, 165, 1890, 156, 83, 2296, 496, 13, 145, 1032, 61, 181, 81, 82, 36803, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802]
#   Input Words: best afternoon snack ever put bag way school work great source protein product natural gluten free
#
# Summary
#   Word Ids:       [25, 81, 82, 258]
#   Response Words: best gluten free snack
#  Ground Truth: great gluten free snack
#
#
# Text
#   Word Ids:    [13305, 746, 845, 1017, 695, 1472, 1458, 1445, 1017, 3178, 2545, 60, 4367, 149, 1064, 771, 433, 1285, 36801, 1874, 1802, 1472, 36803, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802]
#   Input Words: confess addicted kind bars first try blueberry pistachio bars sealed problem delicious fairly low calories sometimes use meal feel satisfied try
#
# Summary
#   Word Ids:       [60, 44, 60, 258]
#   Response Words: delicious and delicious snack
#  Ground Truth: addicted to kind bars
#
#
# Text
#   Word Ids:    [32, 1017, 1089, 1082, 1874, 1576, 258, 21, 684, 24, 36803, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802]
#   Input Words: love bars run quickly feel guilty snack tasty yet healthy
#
# Summary
#   Word Ids:       [13, 258, 70, 258]
#   Response Words: great snack for snack
#  Ground Truth: these are the best
#
# ** Epoch   3/5 Batch   50/423 - Batch Loss:  4.150, seconds: 83.82
# ** Epoch   3/5 Batch  100/423 - Batch Loss:  3.879, seconds: 83.05
# Average loss: 4.013
# Saving model
# ** Epoch   3/5 Batch  150/423 - Batch Loss:  3.957, seconds: 83.89
# ** Epoch   3/5 Batch  200/423 - Batch Loss:  3.881, seconds: 83.54
# Average loss: 3.922
# Saving model
# ** Epoch   3/5 Batch  250/423 - Batch Loss:  3.879, seconds: 82.26
# ** Epoch   3/5 Batch  300/423 - Batch Loss:  3.834, seconds: 82.49
# Average loss: 3.834
# Saving model
# history: [3, 3.834, 3.7855482]
#
# Test: epoch 3 loss: 3.7855482
#
#
# Text
#   Word Ids:    [25, 2127, 258, 165, 1890, 156, 83, 2296, 496, 13, 145, 1032, 61, 181, 81, 82, 36803, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802]
#   Input Words: best afternoon snack ever put bag way school work great source protein product natural gluten free
#
# Summary
#   Word Ids:       [25, 258, 165, 453, 824]
#   Response Words: best snack ever there eaten
#  Ground Truth: great gluten free snack
#
#
# Text
#   Word Ids:    [13305, 746, 845, 1017, 695, 1472, 1458, 1445, 1017, 3178, 2545, 60, 4367, 149, 1064, 771, 433, 1285, 36801, 1874, 1802, 1472, 36803, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802]
#   Input Words: confess addicted kind bars first try blueberry pistachio bars sealed problem delicious fairly low calories sometimes use meal feel satisfied try
#
# Summary
#   Word Ids:       [60, 44, 24, 258]
#   Response Words: delicious and healthy snack
#  Ground Truth: addicted to kind bars
#
#
# Text
#   Word Ids:    [32, 1017, 1089, 1082, 1874, 1576, 258, 21, 684, 24, 36803, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802]
#   Input Words: love bars run quickly feel guilty snack tasty yet healthy
#
# Summary
#   Word Ids:       [48, 258, 1017, 1017]
#   Response Words: yummy snack bars bars
#  Ground Truth: these are the best
#
# ** Epoch   4/5 Batch   50/423 - Batch Loss:  3.881, seconds: 84.36
# ** Epoch   4/5 Batch  100/423 - Batch Loss:  3.616, seconds: 84.18
# Average loss: 3.745
# Saving model
# ** Epoch   4/5 Batch  150/423 - Batch Loss:  3.677, seconds: 83.89
# ** Epoch   4/5 Batch  200/423 - Batch Loss:  3.612, seconds: 82.66
# Average loss: 3.655
# Saving model
# ** Epoch   4/5 Batch  250/423 - Batch Loss:  3.639, seconds: 84.83
# ** Epoch   4/5 Batch  300/423 - Batch Loss:  3.572, seconds: 81.46
# Average loss: 3.578
# Saving model
# history: [4, 3.578, 3.516473]
#
# Test: epoch 4 loss: 3.516473
#
#
# Text
#   Word Ids:    [25, 2127, 258, 165, 1890, 156, 83, 2296, 496, 13, 145, 1032, 61, 181, 81, 82, 36803, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802]
#   Input Words: best afternoon snack ever put bag way school work great source protein product natural gluten free
#
# Summary
#   Word Ids:       [25, 258, 462, 1128]
#   Response Words: best snack have tried
#  Ground Truth: great gluten free snack
#
#
# Text
#   Word Ids:    [13305, 746, 845, 1017, 695, 1472, 1458, 1445, 1017, 3178, 2545, 60, 4367, 149, 1064, 771, 433, 1285, 36801, 1874, 1802, 1472, 36803, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802]
#   Input Words: confess addicted kind bars first try blueberry pistachio bars sealed problem delicious fairly low calories sometimes use meal feel satisfied try
#
# Summary
#   Word Ids:       [60, 44, 157, 1017]
#   Response Words: delicious and chocolate bars
#  Ground Truth: addicted to kind bars
#
#
# Text
#   Word Ids:    [32, 1017, 1089, 1082, 1874, 1576, 258, 21, 684, 24, 36803, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802]
#   Input Words: love bars run quickly feel guilty snack tasty yet healthy
#
# Summary
#   Word Ids:       [48, 44, 157, 1017]
#   Response Words: yummy and chocolate bars
#  Ground Truth: these are the best
#
# ** Epoch   5/5 Batch   50/423 - Batch Loss:  3.600, seconds: 92.36
# ** Epoch   5/5 Batch  100/423 - Batch Loss:  3.384, seconds: 84.66
# Average loss: 3.494
# Saving model
# ** Epoch   5/5 Batch  150/423 - Batch Loss:  3.473, seconds: 83.99
# ** Epoch   5/5 Batch  200/423 - Batch Loss:  3.386, seconds: 82.12
# Average loss: 3.437
# Saving model
# ** Epoch   5/5 Batch  250/423 - Batch Loss:  3.421, seconds: 83.83
# ** Epoch   5/5 Batch  300/423 - Batch Loss:  3.344, seconds: 85.23
# Average loss: 3.353
# Saving model
# history: [5, 3.353, 3.307459]
#
# Test: epoch 5 loss: 3.307459
#
#
# Text
#   Word Ids:    [25, 2127, 258, 165, 1890, 156, 83, 2296, 496, 13, 145, 1032, 61, 181, 81, 82, 36803, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802]
#   Input Words: best afternoon snack ever put bag way school work great source protein product natural gluten free
#
# Summary
#   Word Ids:       [13, 54, 44, 24]
#   Response Words: great taste and healthy
#  Ground Truth: great gluten free snack
#
#
# Text
#   Word Ids:    [13305, 746, 845, 1017, 695, 1472, 1458, 1445, 1017, 3178, 2545, 60, 4367, 149, 1064, 771, 433, 1285, 36801, 1874, 1802, 1472, 36803, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802]
#   Input Words: confess addicted kind bars first try blueberry pistachio bars sealed problem delicious fairly low calories sometimes use meal feel satisfied try
#
# Summary
#   Word Ids:       [60, 44, 24, 258]
#   Response Words: delicious and healthy snack
#  Ground Truth: addicted to kind bars
#
#
# Text
#   Word Ids:    [32, 1017, 1089, 1082, 1874, 1576, 258, 21, 684, 24, 36803, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802, 36802]
#   Input Words: love bars run quickly feel guilty snack tasty yet healthy
#
# Summary
#   Word Ids:       [60, 44, 24, 258]
#   Response Words: delicious and healthy snack
#  Ground Truth: these are the best

# %%
history=pd.DataFrame(history, columns=['epochs','loss','val_loss'])
from matplotlib import pyplot 
pyplot.plot(history['epochs'],history['loss'], label='train') 
pyplot.plot(history['epochs'],history['val_loss'], label='test') 
pyplot.legend() 
pyplot.show()

# %%
history
# Out:
#    epochs   loss  val_loss
# 0       1  4.909  4.832585
# 1       2  4.251  4.366992
# 2       3  3.834  3.785548
# 3       4  3.578  3.516473
# 4       5  3.353  3.307459

# %%
#Evaluate results¶
#Because our task is simple and the output is straight-forward, we will use MAE metric to evaluate the trained model during the epochs. Compute the value of the metric for the output from each epoch.

# %%
for i, (gts, predictions, invalid_number_prediction_count) in enumerate(zip(all_ground_truth,
                                                                            all_model_predictions,
                                                                            invalid_number_prediction_counts), 1):
       

          mae=mean_absolute_error_texts(gts, predictions)
          print("Epoch: %i, MAE: %f, Invalid numbers: %i" % (i, mae, invalid_number_prediction_count))
# Out:
# Epoch: 1, MAE: 42.857143, Invalid numbers: 42
# Epoch: 2, MAE: 42.857143, Invalid numbers: 34
# Epoch: 3, MAE: 61.721340, Invalid numbers: 58
# Epoch: 4, MAE: 73.029674, Invalid numbers: 40
# Epoch: 5, MAE: 83.333333, Invalid numbers: 43

# %%
#random = np.random.randint(0,3000)
#text = news_texts_filtered[random]
model_predictions = []
ground_truth = []
invalid_number_prediction_count = 0
checkpoint = logs_path + 'best_so_far_model.ckpt' 
print("\n----Prepare evaluation")
for ii in range(100):
    random = np.random.randint(21700,27125)
    text = news_texts_filtered[random]

    #random = np.random.randint(3000,len(news_texts_filtered))
        
    loaded_graph = tf.Graph()
    with tf.Session(graph=loaded_graph) as sess:
                  loader = tf.train.import_meta_graph(checkpoint + '.meta')
                  loader.restore(sess, checkpoint)
                  input_data = loaded_graph.get_tensor_by_name('input_data:0')
                  logits = loaded_graph.get_tensor_by_name('predictions:0')
                  text_length = loaded_graph.get_tensor_by_name('text_len:0')
                  summary_length = loaded_graph.get_tensor_by_name('summary_len:0')
                  keep_prob = loaded_graph.get_tensor_by_name('dropout_probs:0')
                  result_logits = sess.run(logits, {input_data: [text]*batch_size, 
                  summary_length: [np.random.randint(5,8)], 
                  text_length: [len(text)]*batch_size,
                  keep_prob: 1.0})[0] 

                  pad = word2int[TOKEN_PAD] 
                  eos = word2int[TOKEN_EOS] 
                  Y=''.join(int2word[i] for i in result_logits if i !=pad)
                  O=''.join(int2word[i] for i in news_summaries_filtered[random] if i!=pad)
                     
                  if mean_absolute_error_texts([Y],[O]) > 90:
                  
                     print('        ')
                     print('        ')
                     #print('\nOriginal Text:', input_sentence)

                     print('\nText')
                     print('  Word Ids:    {}'.format([i for i in text]))
                     print('  Input Words: {}'.format(" ".join( int2word[i] for i in text if i!=eos)))

                     print('\nSummary')
                     print('  Word Ids:       {}'.format([i for i in result_logits if i != pad]))
                     print('  Response Words: {}'.format(" ".join(int2word[i] for i in result_logits if i!=pad )))
                     print(' Ground Truth: {}'.format(" ".join(int2word[i] for i in news_summaries_filtered[random] if i!=pad)))
                     print('        ')
                     print('        ')
 
model_predictions.append(result_logits)
ground_truth.append(news_summaries_filtered[random])         
print('\n...prepare evaluation finished.')
# Out:
# ----Prepare evaluation
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [2063, 318, 1636, 433, 112, 2261, 12370, 3165, 12150, 1782, 1636, 2068, 36803]
#   Input Words: tender light popcorn use back basics stainless steel stove top popcorn popper
#
# Summary
#   Word Ids:       [1476, 2791, 1106, 1401]
#   Response Words: cutter advanced corn topping
#  Ground Truth: fresh and light popcorn
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [10590, 36801, 3, 781, 1723, 2, 1129, 2901, 14597, 1957, 5892, 1274, 1129, 879, 872, 1106, 33862, 1578, 865, 626, 719, 1216, 517, 1256, 15, 468, 1127, 215, 374, 985, 24, 469, 316, 643, 298, 2407, 1961, 155, 14217, 2881, 6470, 373, 1816, 2022, 4913, 843, 1355, 672, 35, 469, 1871, 719, 4270, 91, 1674, 38, 446, 36803]
#   Input Words: length <UNK> food well recieved dog however closer inspection beef main ingredient however soy wheat corn bumping amount meat quite bit dried beans potatoes nice artificial color shame really fine healthy ingredients make cost something folks willing pay corners cut occasional mix might honestly reading label wish used better ingredients charged bit certainly would feed regular basis
#
# Summary
#   Word Ids:       [4, 1136, 17, 418]
#   Response Words: not worth the money
#  Ground Truth: after researching the ingredients found this
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [5980, 579, 1156, 71, 108, 25, 474, 539, 323, 1082, 519, 36803]
#   Input Words: looked around decent price stuff best could find arrived quickly expected
#
# Summary
#   Word Ids:       [13, 71, 70, 6031]
#   Response Words: great price for caveats
#  Ground Truth: it is what it is
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [13, 83, 92, 1108, 83, 309, 1806, 1203, 2951, 149, 11954, 92, 3, 495, 5230, 57, 3, 400, 174, 5569, 175, 202, 19336, 400, 1113, 401, 92, 5510, 2055, 295, 4582, 496, 12383, 12128, 5510, 36803]
#   Input Words: great way buy cereal way help mother lives fixed low income buy food shipped directly home food get cold colorado weather bad roads get grocery store buy groceries hope amazon continues work companies expand groceries
#
# Summary
#   Word Ids:       [13, 1108, 429, 71]
#   Response Words: great cereal terrible price
#  Ground Truth: great way to help people
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [374, 1567, 68, 13, 512, 1945, 154, 1528, 425, 4116, 38, 293, 777, 2881, 4116, 425, 1064, 630, 151, 2342, 293, 1176, 3901, 18, 3852, 1450, 0, 1, 61, 36803]
#   Input Words: really enjoy flavor great ice refreshing much less sugar carbs regular juice need cut carbs sugar calories unique alternative orange juice bought sale expensive otherwise tell good quality product
#
# Summary
#   Word Ids:       [13, 151, 990, 990]
#   Response Words: great alternative soda soda
#  Ground Truth: flavorful and clean taste
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [1547, 36801, 486, 135, 391, 3147, 772, 1355, 71, 3096, 1547, 186, 479, 1953, 245, 1228, 479, 86, 36803]
#   Input Words: two <UNK> absolutely loved gave four stars wish price lower two dogs one package last long one day
#
# Summary
#   Word Ids:       [30, 186, 32, 64]
#   Response Words: my dogs love these
#  Ground Truth: my dogs loved these
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [663, 1386, 373, 2584, 14369, 466, 777, 433, 1585, 5138, 2376, 466, 2965, 849, 1133, 1969, 585, 4945, 402, 684, 753, 9592, 4056, 295, 36803]
#   Input Words: box packets mix several glasses drink need use entire packet per drink prompt delivery packaged safely shipping damage disappointed yet service orders placed amazon
#
# Summary
#   Word Ids:       [13, 61, 53, 4755]
#   Response Words: great product poor packing
#  Ground Truth: white grape drink mix
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [133, 374, 110, 914, 512, 661, 91, 7283, 799, 640, 661, 827, 307, 307, 316, 512, 661, 9950, 36803]
#   Input Words: kids really like making ice cream would suggest using heavy cream instead half half make ice cream richer
#
# Summary
#   Word Ids:       [0, 108, 100, 512]
#   Response Words: good stuff but ice
#  Ground Truth: very good ice cream
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [60, 503, 716, 321, 3, 401, 5415, 418, 2546, 3290, 36803]
#   Input Words: delicious seasoning buying health food store alot money stopped selling
#
# Summary
#   Word Ids:       [5218, 44, 5218, 36]
#   Response Words: tastier and tastier than
#  Ground Truth: delicious for pasta and pizza
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [1128, 539, 0, 157, 2686, 1748, 1749, 1228, 5177, 5053, 539, 1022, 157, 2686, 1748, 1749, 9543, 6630, 54, 374, 0, 157, 374, 0, 54, 1748, 1749, 17310, 2603, 5053, 374, 1450, 1288, 17439, 672, 1748, 1749, 54, 1890, 327, 101, 2389, 758, 509, 156, 324, 2617, 36803]
#   Input Words: tried find good chocolate covered sunflower seeds long young couldnt find easily chocolate covered sunflower seeds yankee traders taste really good chocolate really good taste sunflower seeds coworker said couldnt really tell guess becasue used sunflower seeds taste put little next probably eat whole bag days thank
#
# Summary
#   Word Ids:       [25, 1749, 462, 1128, 405]
#   Response Words: best seeds have tried out
#  Ground Truth: chocolate covered sunflower seeds yum
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [87, 1243, 358, 36801, 179, 110, 1708, 6393, 110, 3874, 179, 479, 1129, 277, 466, 445, 467, 661, 425, 995, 1205, 156, 1355, 811, 179, 3095, 13, 36803]
#   Input Words: wife slightly different <UNK> coffee like mine darker like milder coffee one however right drink daily without cream sugar second pound bag wish found coffee sooner great
#
# Summary
#   Word Ids:       [0, 179, 70, 17, 115]
#   Response Words: good coffee for the go
#  Ground Truth: great mild medium flavored coffee
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [402, 331, 594, 486, 54, 1636, 374, 357, 5817, 331, 594, 1371, 479, 3352, 4175, 846, 54, 1650, 594, 626, 21, 36803]
#   Input Words: disappointed mini bags absolutely taste popcorn really looking forward mini bags solution one person understand bland taste larger bags quite tasty
#
# Summary
#   Word Ids:       [0, 100, 4, 17, 25]
#   Response Words: good but not the best
#  Ground Truth: act ii butter mini bags
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [1547, 186, 479, 640, 6191, 186, 32, 2886, 588, 5302, 6538, 9295, 781, 679, 640, 6191, 881, 12695, 452, 91, 6250, 781, 719, 1045, 567, 2513, 110, 5953, 3312, 9295, 1797, 781, 36803]
#   Input Words: two dogs one heavy chewer dogs love toy take turns stealing held well even heavy chewer gets ahold sure would hold well bit thin pieces stick like foot head held surprisingly well
#
# Summary
#   Word Ids:       [30, 186, 32, 9]
#   Response Words: my dogs love it
#  Ground Truth: great for heavy chewer
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [2, 3167, 3797, 2020, 4576, 1702, 12955, 1472, 3, 5632, 156, 663, 2, 11567, 13637, 2287, 5038, 1783, 8319, 12240, 8317, 110, 400, 2, 910, 24711, 579, 5014, 474, 1006, 3041, 1056, 6539, 277, 6786, 1634, 2, 4991, 5430, 758, 5325, 23659, 374, 1774, 91, 831, 710, 827, 4210, 1782, 38, 3, 8138, 110, 530, 190, 5987, 2675, 5285, 6786, 3797, 11592, 1687, 651, 464, 4179, 2, 2669, 2295, 3, 1122, 127, 36803]
#   Input Words: dog grew purina products trust name eager try food removed bag box dog eagerly sniffing seemed excited contents opened began act like get dog treats hopping around begging could wait poured dish gobbled right unlike normal dog chow left eat hungry rationed really think would stop gone instead sprinkle top regular food dole like treat problems digesting chef michael unlike purina beneful original pounds tested ago dog point view food totally awesome
#
# Summary
#   Word Ids:       [30, 2, 345, 9]
#   Response Words: my dog loves it
#  Ground Truth: my dog loves chef michael
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [3561, 61, 307, 1771, 1784, 36801, 11267, 1128, 479, 1784, 186, 515, 36803]
#   Input Words: returning product half cans dented <UNK> falling tried one dented dogs impressed
#
# Summary
#   Word Ids:       [17, 1771, 73, 429]
#   Response Words: the cans is terrible
#  Ground Truth: my dogs were not impressed
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [256, 61, 687, 273, 439, 0, 1855, 43, 3056, 508, 5415, 1735, 571, 6128, 1216, 4071, 108, 110, 253, 61, 1803, 546, 36803]
#   Input Words: excellent product touch salt packaging good keep fresh plan eating alot crackers near future dried fruits stuff like happy product recommend highly
#
# Summary
#   Word Ids:       [907, 73, 17, 25]
#   Response Words: where is the best
#  Ground Truth: back to nature crispy wheats cracker
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [8042, 1469, 944, 1693, 3, 811, 1804, 2020, 13, 1046, 92, 61, 436, 36803]
#   Input Words: citric acid seems basic food found many products great place buy product thanks
#
# Summary
#   Word Ids:       [13, 151, 84, 990]
#   Response Words: great alternative to soda
#  Ground Truth: basic food great price
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [374, 94, 110, 1497, 632, 466, 26, 174, 110, 26, 172, 1050, 1059, 174, 26, 1397, 1855, 716, 1228, 729, 32, 36803]
#   Input Words: really tastes like ginger honey drink hot cold like hot tea son likes cold hot inexpensive keep buying long sold love
#
# Summary
#   Word Ids:       [25, 271, 466, 165]
#   Response Words: best tasting drink ever
#  Ground Truth: this tastes so good
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [654, 1128, 256, 479, 91, 7283, 36803]
#   Input Words: flavors tried excellent one would suggest
#
# Summary
#   Word Ids:       [0, 54, 100, 4, 154]
#   Response Words: good taste but not much
#  Ground Truth: not as good as the others
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [1872, 0, 1182, 1796, 811, 12892, 1062, 20533, 706, 205, 1210, 1211, 295, 3184, 2630, 268, 11856, 2291, 552, 5466, 5467, 608, 83, 36803]
#   Input Words: shocked good reviews sludge found akin watery mud horrible item eligible return amazon unfortunately total rip splurge keurig cups lesson learned hard way
#
# Summary
#   Word Ids:       [689, 689, 8141, 462, 165, 662, 7130]
#   Response Words: worst worst gopher have ever had monster
#  Ground Truth: money down the drain
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [544, 746, 798, 608, 102, 5498, 1005, 1114, 3278, 1255, 104, 520, 295, 1472, 110, 721, 982, 88, 172, 36803]
#   Input Words: husband addicted tips hard time finding local stores thrilled able order line amazon try like strong flavorful favorite tea
#
# Summary
#   Word Ids:       [25, 172, 165, 662, 539]
#   Response Words: best tea ever had find
#  Ground Truth: the very best british tea
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [1205, 6011, 59, 18582, 508, 1128, 16056, 2020, 3579, 1053, 89, 221, 86, 2201, 639, 6233, 3052, 36801, 590, 2, 1315, 3576, 58, 221, 1547, 3772, 2802, 1646, 13, 128, 205, 36803]
#   Input Words: pound poodle always resistant eating tried sunrise products cesar eats breakfast every day additional goodness remove lid <UNK> seconds dog crazy purchased delivered every two months subscribe save great deal item
#
# Summary
#   Word Ids:       [30, 2, 345, 9]
#   Response Words: my dog loves it
#  Ground Truth: fantastic size for small dogs
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [21, 4444, 258, 3, 149, 346, 2132, 793, 80, 641, 91, 8116, 781, 659, 5628, 3969, 36803]
#   Input Words: tasty healty snack food low fat content still satisfying crisp would pair well cheese dips parties
#
# Summary
#   Word Ids:       [21, 100, 4, 24]
#   Response Words: tasty but not healthy
#  Ground Truth: tasty and healthy snack
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [1339, 179, 1116, 556, 466, 1486, 486, 345, 1385, 1128, 374, 515, 68, 1565, 123, 1385, 1093, 244, 91, 546, 1803, 1486, 179, 2305, 71, 2308, 36803]
#   Input Words: ordered coffee mom since drink decaf absolutely loves also tried really impressed flavor wonderfully smooth also smells amazing would highly recommend decaf coffee anyone price reasonable
#
# Summary
#   Word Ids:       [30, 5356, 345, 9]
#   Response Words: my girlfriend loves it
#  Ground Truth: great flavor and price
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [2, 345, 3, 2923, 1674, 16244, 91, 5023, 1172, 3, 6256, 400, 579, 508, 3, 486, 32, 1948, 716, 36803]
#   Input Words: dog loves food soon feed scarfs would sniff old food eventually get around eating food absolutely love definitely buying
#
# Summary
#   Word Ids:       [30, 2, 345, 33, 3]
#   Response Words: my dog loves this food
#  Ground Truth: blue buffalo weight control
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [1156, 1490, 3077, 3354, 0, 469, 316, 60, 3, 3948, 346, 781, 1136, 418, 1355, 585, 3498, 1288, 7818, 556, 1804, 2366, 1574, 384, 3948, 346, 36803]
#   Input Words: decent cook knows takes good ingredients make delicious food duck fat well worth money wish shipping costly guess suck since many places purchase quantity duck fat
#
# Summary
#   Word Ids:       [21, 100, 4, 17, 25]
#   Response Words: tasty but not the best
#  Ground Truth: the most delicious thanks giving ever
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [1128, 179, 52, 21, 781, 32, 32, 32, 1463, 736, 36801, 4088, 179, 20, 1040, 156, 390, 1, 104, 13309, 2584, 594, 4330, 2366, 179, 1040, 1855, 43, 179, 358, 6223, 2291, 179, 1129, 3421, 2291, 9463, 11044, 179, 525, 1344, 42, 2291, 17941, 3503, 179, 1433, 2439, 72, 1433, 672, 2439, 42, 72, 5438, 63, 36801, 5477, 72, 672, 36803]
#   Input Words: tried coffee expect tasty well love love love company packs <UNK> individual coffee wonderful plastic bag high quality order consisted several bags manufacturer places coffee plastic keep fresh coffee different bottom keurig coffee however fits keurig platinum series coffee maker aware new keurig vue brewer coffee pods fit machine pods used fit new machine gimmick sell <UNK> replace machine used
#
# Summary
#   Word Ids:       [0, 179, 202, 71]
#   Response Words: good coffee bad price
#  Ground Truth: san francisco bay excellent coffee
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [0, 399, 179, 318, 181, 476, 68, 123, 532, 635, 229, 1107, 5579, 8444, 592, 476, 91, 5037, 772, 476, 68, 2078, 957, 1883, 1326, 476, 36803]
#   Input Words: good cup coffee light natural vanilla flavor smooth bitter aftertaste far superior gloria jean french vanilla would given stars vanilla flavor tad stronger truly hint vanilla
#
# Summary
#   Word Ids:       [721, 399, 399, 399]
#   Response Words: strong cup cup cup
#  Ground Truth: pleasant cup of coffee
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [2, 1059, 2675, 11587, 1289, 3, 1481, 91, 1472, 1217, 3, 781, 1890, 4700, 172, 12974, 273, 82, 553, 5351, 3038, 116, 135, 0, 2071, 3145, 579, 860, 8911, 1039, 36803]
#   Input Words: dog likes chef michaels canned food thought would try dry food well put bowl tea spoons salt free chicken broth went nuts loved good teeth dances around kitchen appear dinner
#
# Summary
#   Word Ids:       [30, 2, 345, 9]
#   Response Words: my dog loves it
#  Ground Truth: my dog loves this stuff
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [1440, 945, 316, 626, 21, 1899, 1216, 2248, 240, 503, 778, 1528, 1698, 8010, 1698, 1712, 9052, 1698, 1490, 529, 240, 480, 1440, 327, 240, 433, 307, 5138, 2881, 112, 7622, 751, 777, 298, 945, 409, 21, 316, 1285, 1948, 36803]
#   Input Words: noodles quick make quite tasty comes dried vegetables spicy seasoning made less minutes stovetop minutes water boil minutes cook fan spicy foods noodles little spicy use half packet cut back spiciness sodium need something quick easy tasty make meal definitely
#
# Summary
#   Word Ids:       [21, 100, 4, 17, 25]
#   Response Words: tasty but not the best
#  Ground Truth: quick and tasty best noodles
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [110, 1426, 659, 68, 672, 2173, 3586, 827, 1957, 374, 1581, 92, 36803]
#   Input Words: like lot cheese flavor used ground turkey instead beef really enjoyed buy
#
# Summary
#   Word Ids:       [13, 54, 100, 4, 13]
#   Response Words: great taste but not great
#  Ground Truth: if you like cheesy
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [9022, 13, 36801, 32, 149, 751, 976, 62, 1711, 10341, 2617, 36803]
#   Input Words: bouillon great <UNK> love low sodium version please add inventory thank
#
# Summary
#   Word Ids:       [13, 61, 100, 5630]
#   Response Words: great product but fatty
#  Ground Truth: please carry the low sodium version
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [4400, 1317, 20, 507, 71, 1738, 110, 6615, 454, 1355, 756, 757, 36803]
#   Input Words: buttery rich wonderful oil price especially like fact organic wish expiration date
#
# Summary
#   Word Ids:       [20, 61, 100, 18]
#   Response Words: wonderful product but expensive
#  Ground Truth: good flavor good buy
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [0, 60, 21103, 8071, 5972, 6483, 94, 3157, 13, 4175, 202, 1182, 29409, 982, 110, 659, 4151, 1088, 1603, 613, 1106, 1285, 646, 273, 1549, 0, 258, 3454, 2035, 0, 1629, 13, 2608, 659, 666, 957, 654, 91, 154, 2259, 35, 654, 854, 1711, 3363, 54, 35, 1930, 479, 1106, 12003, 12949, 1106, 12003, 1687, 91, 92, 654, 1629, 1, 479, 719, 846, 1014, 1660, 6612, 24, 318, 409, 1511, 36803]
#   Input Words: good delicious utilitarian fills hunger void tastes pleasant great understand bad reviews hammering flavorful like cheese curls people expecting baked corn meal flavored salt yeast good snack anyway reasonably good texture great intolerant cheese spice stronger flavors would much improved better flavors perhaps add varieties taste better call one corn tings unflavored corn tings original would buy flavors texture quality one bit bland overall job designed healthy light easy body
#
# Summary
#   Word Ids:       [0, 100, 4, 17, 25]
#   Response Words: good but not the best
#  Ground Truth: decent taste healthy but very basic
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [9380, 1128, 479, 2706, 35, 1481, 1088, 2603, 463, 110, 11, 805, 1141, 4707, 1129, 309, 9007, 22643, 672, 2802, 1646, 6771, 825, 1122, 1136, 36803]
#   Input Words: buddies tried one night better thought people said tasted like cough syrup may everybody however help headaches partying used subscribe save promotion got totally worth
#
# Summary
#   Word Ids:       [30, 5356, 32, 9]
#   Response Words: my girlfriend love it
#  Ground Truth: good for what it is
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [94, 5508, 29781, 11633, 1749, 316, 1120, 7336, 15213, 1355, 401, 793, 6721, 36803]
#   Input Words: tastes rye pumpernickel caraway seeds make salad event anticipate wish store still stocked
#
# Summary
#   Word Ids:       [13, 54, 100, 153, 110]
#   Response Words: great taste but so like
#  Ground Truth: combination of breads winner
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [3474, 36801, 2109, 1551, 13, 625, 2795, 2702, 2906, 2959, 627, 659, 4349, 479, 277, 7765, 88, 1, 512, 661, 295, 3460, 13, 71, 806, 228, 68, 36803]
#   Input Words: jules <UNK> butter crisps great thick dalmatian style fig spread salty cheese jam one right scoop favorite quality ice cream amazon offers great price substitute cookie flavor
#
# Summary
#   Word Ids:       [13, 70, 17, 71]
#   Response Words: great for the price
#  Ground Truth: natural buttery crisp taste
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [793, 2040, 1731, 4106, 19979, 374, 0, 1887, 8292, 1385, 2003, 0, 12881, 1458, 317, 4106, 538, 15, 530, 353, 4106, 1749, 1022, 35, 56, 538, 36803]
#   Input Words: still trying figure chia seeks really good joints supposedly also omega good regardless blueberry fruit chia bar nice treat makes chia seeds easily better candy bar
#
# Summary
#   Word Ids:       [24, 70, 417, 1511, 345]
#   Response Words: healthy for your body loves
#  Ground Truth: tasty snack easy omega
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [1176, 2226, 1182, 1079, 1484, 298, 1995, 1288, 418, 479, 359, 1774, 541, 416, 418, 767, 608, 539, 776, 467, 2688, 1136, 36803]
#   Input Words: bought going reviews online boxes something inedible guess money one cannot think else waste money know hard find things without allergens worth
#
# Summary
#   Word Ids:       [109, 416, 417, 418]
#   Response Words: don waste your money
#  Ground Truth: good if you like cardboard
#
# ...
#   Input Words: tried find dental treat feed year old yellow lab past months none recommended chews treats trick plain refused upon first sniff took chance greenies based quick dirty research sure glad absolutely devours time flat somewhat picky eater proved fantastic purchase
#
# Summary
#   Word Ids:       [30, 2, 345, 9]
#   Response Words: my dog loves it
#  Ground Truth: my yellow lab loves them
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [12467, 1024, 4154, 202, 1182, 34625, 585, 54, 13, 59, 479, 1484, 731, 585, 5201, 9233, 4874, 12738, 4882, 400, 11226, 14805, 1503, 778, 16401, 895, 9529, 1024, 104, 775, 278, 1355, 91, 11889, 585, 4755, 2545, 11497, 2194, 19929, 914, 21708, 14579, 4755, 585, 812, 1727, 35, 3056, 3666, 602, 36803]
#   Input Words: signed subscription hoping bad reviews flukes shipping taste great always one boxes damaged shipping leaked laundry room contacted retailer get replaced mopped mess made mental note cancel subscription order smaller size wish would address shipping packing problem mentioned site whomever making executive decisions packing shipping needs come better plan customers elsewhere
#
# Summary
#   Word Ids:       [13, 61, 44, 753]
#   Response Words: great product and service
#  Ground Truth: tastes great but packaging needs improvement
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [1481, 632, 154, 10521, 632, 5396, 154, 68, 679, 133, 1540, 0, 71, 883, 110, 2264, 632, 111, 36803]
#   Input Words: thought honey much thinner honey gotten much flavor even kids care good price though like bottles honey came
#
# Summary
#   Word Ids:       [4, 202, 100, 676]
#   Response Words: not bad but prefer
#  Ground Truth: would not buy again
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [1339, 626, 374, 21, 719, 18, 853, 400, 155, 980, 1958, 2133, 0, 57, 778, 1958, 672, 400, 1417, 4270, 755, 1385, 1463, 13660, 3518, 479, 9592, 827, 470, 594, 825, 479, 10164, 1463, 4359, 829, 42, 594, 277, 2218, 1774, 1687, 88, 68, 327, 1327, 825, 2865, 68, 781, 327, 55, 654, 327, 240, 36803]
#   Input Words: ordered quite really tasty bit expensive side get pay cheap jerky gross good home made jerky used get aunt certainly close also company responsive helpful one orders instead getting bags got one emailed company sent three new bags right away think original favorite flavor little sweetness got teriyaki flavor well little sweet flavors little spicy
#
# Summary
#   Word Ids:       [0, 100, 4, 360, 153]
#   Response Words: good but not be so
#  Ground Truth: little pricey but delicious
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [71, 0, 1048, 2109, 1612, 226, 729, 1382, 626, 519, 7834, 357, 2109, 228, 54, 54, 110, 2109, 226, 54, 297, 518, 110, 34612, 900, 202, 4415, 1010, 1953, 1103, 479, 10031, 4367, 566, 226, 278, 3122, 1192, 1629, 15, 3355, 25, 2065, 36803]
#   Input Words: price good compared butter type cookies sold live quite expected primarily looking butter cookie taste taste like butter cookies taste almost exactly like nila wafers bad course wanted package contains one row fairly large cookies size palm say texture nice crumbly best part
#
# Summary
#   Word Ids:       [0, 100, 4, 17, 25]
#   Response Words: good but not the best
#  Ground Truth: meh these are just ok
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [71, 179, 15570, 746, 363, 179, 106, 1855, 179, 13, 71, 36803]
#   Input Words: price coffee rising addicted brand coffee pack keep coffee great price
#
# Summary
#   Word Ids:       [179, 2326, 2326, 2326]
#   Response Words: coffee pricing pricing pricing
#  Ground Truth: wake up to this deal
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [61, 441, 4367, 849, 489, 2033, 165, 561, 975, 5770, 518, 110, 358, 4018, 15436, 1774, 778, 55, 2653, 558, 2109, 2653, 373, 5770, 43, 1289, 1106, 327, 622, 10445, 1538, 198, 1106, 5770, 1722, 853, 1056, 60, 36803]
#   Input Words: product priced fairly delivery fast affordable ever heinz india relish exactly like different pickle relishes think made sweet pickles bread butter pickles mix relish fresh canned corn little onion bell pepper perfect corn relish summer side dish delicious
#
# Summary
#   Word Ids:       [907, 73, 17, 25]
#   Response Words: where is the best
#  Ground Truth: great base for corn relish
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [1629, 1663, 15, 3184, 54, 474, 472, 54, 1663, 721, 54, 507, 9672, 1663, 1061, 567, 3130, 2320, 36803]
#   Input Words: texture pineapple nice unfortunately taste could barely taste pineapple strong taste oil overpowered pineapple ate pieces threw rest
#
# Summary
#   Word Ids:       [4, 202, 100, 4, 202]
#   Response Words: not bad but not bad
#  Ground Truth: will not buy again
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [1679, 4026, 205, 1385, 8054, 0, 6203, 2584, 3292, 1523, 1654, 1782, 36801, 5786, 1039, 126, 4894, 7263, 1129, 8054, 101, 3787, 126, 0, 36803]
#   Input Words: disapointed particular item also tenderloin good entertain several times year hopes top <UNK> suitable dinner guests sadly mistaken however tenderloin next week guests good
#
# Summary
#   Word Ids:       [17, 25, 28, 17, 2320]
#   Response Words: the best in the rest
#  Ground Truth: very chewy and hard to eat
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [4684, 218, 375, 2, 530, 3455, 3318, 1547, 1348, 646, 3401, 110, 588, 7326, 263, 566, 6085, 3461, 4647, 11115, 6085, 2889, 2, 13807, 9527, 1101, 4647, 11115, 807, 34673, 61, 2545, 6085, 12098, 3855, 2, 359, 316, 6085, 2346, 696, 4647, 4032, 400, 1744, 1146, 3401, 574, 2664, 979, 896, 61, 218, 0, 807, 496, 781, 36803]
#   Input Words: clever idea give dog treat offering lick two bacon flavored liquid like take cap bottle large ball similar roll deodorant ball offer dog lap appears actual roll deodorant container repurposed product problem ball rotate freely dog cannot make ball turn tongue roll thumb get wash hands liquid brown sticky mediocre rating product idea good container work well
#
# Summary
#   Word Ids:       [30, 2, 501, 9]
#   Response Words: my dog does it
#  Ground Truth: dispenser does not work well
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [32, 798, 1079, 1114, 9871, 4359, 1484, 479, 1763, 2218, 756, 757, 4359, 112, 5241, 7762, 375, 986, 7762, 1871, 663, 8319, 1472, 172, 1871, 4353, 20843, 736, 1211, 4353, 10742, 8498, 3663, 986, 7762, 579, 13, 7381, 1328, 91, 92, 36803]
#   Input Words: love tips online stores inc sent boxes one month away expiration date sent back asked refund give full refund charged box opened try tea charged postage reimburse packs return postage respond wrote receiving full refund around great merchant experience would buy
#
# Summary
#   Word Ids:       [295, 73, 17, 71]
#   Response Words: amazon is the price
#  Ground Truth: good tea not good company
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [1433, 496, 13, 3031, 466, 36801, 596, 847, 4016, 4503, 2798, 701, 1928, 1071, 124, 4470, 438, 179, 1511, 68, 552, 1948, 1136, 2040, 402, 111, 13, 36803]
#   Input Words: pods work great usually drink <UNK> double black diamond recently newmans extra bold dark brew concerned weak coffee body flavor cups definitely worth trying disappointed came great
#
# Summary
#   Word Ids:       [0, 721, 399, 41, 892]
#   Response Words: good strong cup of joe
#  Ground Truth: just as good for less
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [452, 1804, 1088, 4175, 695, 54, 512, 3425, 1712, 3462, 3065, 20879, 533, 42, 740, 8700, 1712, 2624, 2484, 964, 8700, 556, 2188, 10070, 4179, 277, 29, 36803]
#   Input Words: sure many people understand first taste ice sparkling water flashback childhood swore drinking new york seltzer water ive morning loss seltzer since discontinued decade ago right world
#
# Summary
#   Word Ids:       [9, 73, 1191, 1191, 1191]
#   Response Words: it is cherry cherry cherry
#  Ground Truth: greatest tasting water since
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [825, 902, 106, 695, 1128, 539, 479, 905, 25, 374, 110, 1629, 1958, 110, 369, 744, 1385, 110, 6507, 1958, 7179, 479, 358, 6507, 5207, 36687, 514, 758, 1089, 1953, 608, 1163, 1958, 409, 2839, 11219, 2740, 1580, 825, 0, 68, 374, 1629, 36803]
#   Input Words: got sampler pack first tried find one liked best really like texture jerky like real thing also like primal jerky tend one different primal softer oozy difficult eat run package hard open jerky easy throw ziploc messy least got good flavor really texture
#
# Summary
#   Word Ids:       [17, 25, 1958, 462, 1128]
#   Response Words: the best jerky have tried
#  Ground Truth: best of the vegan dream jerky
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [357, 61, 11064, 12114, 253, 539, 295, 1114, 3036, 71, 436, 914, 816, 36803]
#   Input Words: looking product relatives overseas happy find amazon stores retail price thanks making available
#
# Summary
#   Word Ids:       [295, 73, 17, 71]
#   Response Words: amazon is the price
#  Ground Truth: best values on amazon stores
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [13, 128, 11324, 186, 32, 245, 1228, 102, 11779, 1082, 6, 36803]
#   Input Words: great deal antlers dogs love last long time arrive quickly advertised
#
# Summary
#   Word Ids:       [30, 186, 32, 341]
#   Response Words: my dogs love em
#  Ground Truth: great deal on natural antlers
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [1523, 1172, 1052, 4573, 81, 2608, 4659, 539, 1634, 3, 1330, 1948, 3421, 3283, 94, 13, 110, 20617, 1330, 253, 5778, 2174, 1330, 1291, 36803]
#   Input Words: year old daughter diagnosed gluten intolerant quest find normal food pasta definitely fits bill tastes great like semolina pasta happy sister told pasta choice
#
# Summary
#   Word Ids:       [13, 81, 82, 1330]
#   Response Words: great gluten free pasta
#  Ground Truth: the best gf pasta
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [186, 32, 11103, 11104, 3565, 479, 719, 1383, 1731, 8294, 6085, 2769, 32, 1738, 110, 3899, 23933, 530, 102, 5892, 433, 433, 1875, 12, 460, 13, 3119, 251, 5817, 3663, 21, 8334, 5658, 12, 13, 11107, 61, 0, 71, 36803]
#   Input Words: dogs love lickety stik took one bit longer figure roller ball done love especially like personal interaction treat time main use use giving medicine works great girl looks forward receiving tasty licks taking medicine great innovative product good price
#
# Summary
#   Word Ids:       [30, 88, 345, 9]
#   Response Words: my favorite loves it
#  Ground Truth: both dogs love it
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [758, 2426, 4367, 3854, 32, 1366, 5607, 172, 1491, 5980, 298, 110, 811, 1240, 3571, 1530, 7054, 172, 36803]
#   Input Words: eat changs fairly often love jasmine blackberry tea serve looked something like found china mist delighted exact tea
#
# Summary
#   Word Ids:       [30, 88, 172, 594]
#   Response Words: my favorite tea bags
#  Ground Truth: exactly pf changs tea
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [695, 338, 529, 74, 1429, 2603, 771, 305, 298, 945, 409, 205, 1158, 316, 327, 35, 2916, 2201, 2964, 374, 962, 4225, 36002, 110, 1212, 1216, 1990, 574, 2762, 43, 2964, 91, 2434, 5138, 4225, 36002, 713, 36803]
#   Input Words: first huge fan instant meals said sometimes mood something quick easy item okay make little better adding additional veggies really helps broccoli florets like tiny dried bits brown paper fresh veggies would leave packet broccoli florets completely
#
# Summary
#   Word Ids:       [0, 108, 100, 153, 154]
#   Response Words: good stuff but so much
#  Ground Truth: ok but certainly not gourmet
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [2, 345, 2, 3, 3395, 543, 4319, 3693, 3, 28890, 1044, 1307, 345, 36803]
#   Input Words: dog loves dog food switch another joint supplement food unavailability issues lucy loves
#
# Summary
#   Word Ids:       [2, 345, 345, 3]
#   Response Words: dog loves loves food
#  Ground Truth: happy hips makes my dog happy
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [1574, 2802, 1646, 1484, 1763, 110, 327, 3489, 827, 1433, 71, 13, 544, 3129, 179, 957, 2819, 592, 593, 1129, 374, 110, 774, 68, 71, 3622, 327, 661, 3080, 156, 91, 375, 3147, 772, 92, 566, 4868, 3032, 36803]
#   Input Words: purchase subscribe save boxes month like little filters instead pods price great husband thinks coffee stronger previous french roast however really like robust flavor price adds little cream resealable bag would give four stars buy large airtight jar
#
# Summary
#   Word Ids:       [0, 179, 202, 71]
#   Response Words: good coffee bad price
#  Ground Truth: robust taste packaging could be better
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [20, 3811, 13769, 553, 555, 2, 667, 2298, 591, 7188, 515, 248, 470, 6292, 9381, 4459, 345, 61, 3811, 695, 825, 15175, 112, 321, 24, 782, 5212, 2065, 191, 142, 21570, 2767, 186, 321, 7761, 511, 2071, 1116, 36803]
#   Input Words: wonderful rescue thrived chicken soup dog lover soul read nutrients impressed value getting gsd glossy coat loves product rescue first got nurse back health healthy balanced joy part life nutrition vitally important dogs health learn brush teeth mom
#
# Summary
#   Word Ids:       [25, 530, 70, 17, 2383]
#   Response Words: best treat for the market
#  Ground Truth: nutritional value for your dog
#
#
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/best_so_far_model.ckpt
#
#
#
# Text
#   Word Ids:    [479, 3162, 5514, 2248, 1047, 2249, 345, 5139, 375, 1015, 479, 4255, 102, 452, 375, 1528, 55, 4255, 695, 1141, 18105, 995, 479, 1855, 1759, 156, 59, 24, 258, 1856, 327, 599, 36803]
#   Input Words: one ways sneak vegetables picky toddler loves pouches give child one pouch time sure give less sweet pouch first may reject second one keep diaper bag always healthy snack hand little guy
#
# Summary
#   Word Ids:       [30, 133, 32, 9]
#   Response Words: my kids love it
#  Ground Truth: sneaks veggies into toddlers
#
#
#
# ...prepare evaluation finished.

# %%
print("Finish ")
# Out:
# Finish
